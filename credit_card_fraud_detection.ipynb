# %% [markdown]
# <a href="https://colab.research.google.com/github/meghanavanamala/predictiveanalysis/blob/credit-card-fraud-detection/credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
mlg_ulb_creditcardfraud_path = kagglehub.dataset_download('mlg-ulb/creditcardfraud')

print('Data source import complete.')
# Out:
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/creditcardfraud/creditcard.csv

# %%
 data= pd.read_csv("/kaggle/input/creditcardfraud/creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data["Class"].unique()
# Out:
# array([0, 1])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ## splitting the data as target and label data

# %%
x=data.drop(["Class"] , axis =1)
y=data["Class"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test , y_train ,y_test = train_test_split(x , y , test_size=0.3 )

# %% [markdown]
# ## importing all the classification models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
from xgboost import XGBClassifier

# %% [markdown]
# ##  import metrics for evaluating the models

# %%
from sklearn.metrics import accuracy_score , classification_report

# %%
lr=LogisticRegression()
rfc=RandomForestClassifier()
dtc=DecisionTreeClassifier()
xg = XGBClassifier()

# %%
lr.fit(x_train , y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ## doing prediction using logistic regression

# %%
pred= lr.predict(x_test)

# %% [markdown]
# ## checking the score and accuracy of the model

# %%
print(accuracy_score(y_test , pred))
# Out:
# 0.9989232587807076

# %%
print(classification_report(y_test , pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85293
#            1       0.70      0.68      0.69       150
#
#     accuracy                           1.00     85443
#    macro avg       0.85      0.84      0.84     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ## checking for overfitting.....
# clearly the cross validation score is more similar with respect to the cv score  i.e training and test data is performing similar so it can said that the model is trained properly and it can predict well....

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(lr, x, y, cv=5)
print("Cross-validation scores:", scores)
print("Mean CV score:", scores.mean())
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# ##  similarly cheking for the random forest classifier

# %%
rfc.fit(x_train , y_train)
pred1=rfc.predict(x_test)
print(accuracy_score(y_test , pred1))
# Out:
# 0.9995435553526912

# %% [markdown]
# ## random forest classifier  doesn't perform well as it has overfitting condition..

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(rfc, x, y, cv=5)
print("Cross-validation scores:", scores)
print("Mean CV score:", scores.mean())
# Out:
# Cross-validation scores: [0.01776623 0.99963133 0.99915732 0.99964888 0.99938554]
# Mean CV score: 0.8031178617033994

# %% [markdown]
# ## predicting using decision tree

# %%
dtc.fit(x_train , y_train)
pred2=dtc.predict(x_test)
print(accuracy_score(y_test , pred2))
# Out:
# 0.9991807403766253

# %% [markdown]
# ## decision tree gives overtraining data

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(dtc, x, y, cv=5)
print("Cross-validation scores:", scores)
print("Mean CV score:", scores.mean())
# Out:
# Cross-validation scores: [0.00609178 0.99933289 0.99691017 0.99892909 0.99894665]
# Mean CV score: 0.8000421150447883

# %% [markdown]
# ## checking with the xgboost and their performance

# %%
xg.fit(x_train , y_train)
pred3=xg.predict(x_test)
print(accuracy_score(y_test , pred3))
# Out:
# 0.9996137776061234

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(xg, x, y, cv=5)
print("Cross-validation scores:", scores)
print("Mean CV score:", scores.mean())
# Out:
# Cross-validation scores: [0.99866578 0.99964889 0.99901687 0.99959621 0.99938554]
# Mean CV score: 0.9992626593119294

# %% [markdown]
# ## conclusion : so we have seen the four models in which only two are able to perform very well i.e logistic regression and xgboost classfier are two perfect model used for the prediction....
